# %% [markdown]
# # Experiment 1.1
#
# As in the previous experiment 1, the goal is:
#
# * Demonstrate an example of calling the ChatGPT API
# * Solve some of the problems in formatting output
# * Use ChatGPT to (a) pick a medical condition and (b) generate an admission note given some simple patient details
# * Evaluate the output for (a) successful generation of text (b) plausibility of admission note
#
# In order to seed the LLM with some patient information, I start with some patient parameters provided by synthetic data. NHS England prepared a synthetic dataset of A&E presentations. A blog post about it is [here](https://open-innovations.org/blog/2019-01-24-exploring-methods-for-creating-synthetic-a-e-data). The dataset can be accessed from [this website](https://data.england.nhs.uk/dataset/a-e-synthetic-data/resource/81b068e5-6501-4840-a880-a8e7aa56890e#).
#
# A notebook exploring these data is [here](explore-nhse-ae-data.ipynb)
#
# This dataset provides, among other things, the hospital length of stay and whether the patient was admitted. As my interest is in clinical notes that are generated during hospital visits, I'm more interested in inpatients. I will use the length of stay information from the A&E dataset to ask ChatGPT to pick a medical condition that would merit inpatient admission. I also investigate whether, by giving the lengh of stay information, the admission note would indicate a severity that could plausibly (at least barring any unexpected developments in the patient's trajectory) result in a such a stay.
#
# In previous iterations I have already found limitations when evaluating the output on:
#
# * on their readability as admission notes (although as I am not medical, I cannot do a full evaluation)
# * on the plausbility of the medical condition chosen by ChatGPT leading to a hospital visit of this length
#
# However, as I'm currently not able to access ChatGPT v4, I want to save 100 notes using gpt-3.5-turbo-0613, for comparison later. So I will continue with this approach for now.

# %% [markdown]
# ## Set up

# %%
# Reload functions every time
# %load_ext autoreload 
# %autoreload 2

# %%
# Load libraries
import sys
import os
import pandas as pd
from pathlib import Path

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)


# Import the variables that have been set in the init.py folder in the root directory
# These include a constant called PROJECT_ROOT which stores the absolute path to this folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
import init
PROJECT_ROOT = os.getenv("PROJECT_ROOT")

# Add the src folder to sys path, so that the application knows to look there for libraries
sys.path.append(str(Path(PROJECT_ROOT) / 'src'))

# Import function to load data
from data_ingestion.load_data import load_nhse_data

from utils.write_to_json import write_to_json
from utils.load_from_json import load_from_json

from functions.patient_class import Patient

from functions.verify_admission_decision import verify_admission_decision

# %% [markdown]
# ## Load data
#
# Here the function called load_file()
#
# * check if the NHS England datset has already been saved in a local folder called data_store in a parquet format; if so the function returns it
# * if not, it checks for the zip file from the NHSE website and if not downloads it, unzips it and saves it
# * the file is unzipped to csv and read as as pandas dataframe and saved to parquet format

# %%
ed = load_nhse_data()
# ed.head()

# %% [markdown]
# ## Generate 100 instances of a patient with admission notes
#
# Here I pick rows from the A&E dataset at random, and generate admission notes for them. I chose to save these to a json file, rather than to individual text files or to SQL, as this is human readable. You can view the full output [here](../src/data_exports/note_dict_20231002_2120.json)
#
# This uses a class definition called Patient(). To see the script, go to [../src/functions/patient_class.py](../src/functions/patient_class.py) An instance of this class, here referred to as a persona, is a single patient. The instance is populated with the variables retrieved from a single row of the ED dataset loaded above.
#
# The steps are the following:
# * select a row from the A&E data
# * pass the row information to the class definition
#
# In addition, as part of creating the persona, a call to ChatGPT is made using the OpenAI API. Certain details about the patient (listed below) are embedded into the prompt to be passed in. ChatGPT is asked to generate a medical condition, and an admission note.
#
# A sub-function [pick_medical_condition()](../src/functions/pick_medical_condition.py) is called to populate three additional attributes of the persona: the medical condition, their admission note, and their most recent note (which is this case is the admission note, but later this attribute could be something else like a progress note).
#
# The script [pick_medical_condition()](../src/functions/pick_medical_condition.py)
#
# * calls a function [generate_prompt_presenting_condition()](../src/functions/pick_medical_condition.py) (scroll down the file) which populates a ChatGPT prompt with details about the patient. The prompt contains ChatGPT's instructions and requests the ouput in a json format. To see the text of the prompt, go to [pick_medical_condition.txt](../templates/prompt_templates/pick_medical_condition.txt)
# * calls ChatGPT with the prompt. Functions used to call ChatGPT are in [prompt_functions.py](../src/functions/prompt_functions.py)
# * attempts to parse the json output

# %%
attributes = ['Age_Band', 'AE_Arrive_HourOfDay', 'AE_Time_Mins',  'Length_Of_Stay_Days', 'ICD10_Chapter_Code', 'Title', 'Medical_Condition', 'Admission_Note']
note_dict = {}

def row_to_patient(row):
    return Patient(*row)

# %%
while len(note_dict.keys()) < 100:

    for index, persona in ed.sample(1).iterrows():

        Pat = row_to_patient(persona)

        if Pat.Admission_Note != '' and 'failed on json' not in str(Pat.Admission_Note):

            print("Successful admission note for patient with id " + str(index))
            
            note_dict[Pat.id] = {}
            note_dict[Pat.id] = {attr: getattr(Pat, attr) for attr in attributes if hasattr(Pat, attr)}

        else: 

            print("Failed admission note for patient with id " + str(index))

    if len(note_dict.keys()) % 10 == 0:
        write_to_json(note_dict, 'experiment_1.1')

write_to_json(note_dict, 'experiment_1.1')
# Out:
# Failed admission note for patient with id 3209564
# Successful admission note for patient with id 5154297
# Failed admission note for patient with id 3476926
# Failed admission note for patient with id 4071698
# Failed admission note for patient with id 2833307
# Failed admission note for patient with id 121764
# Successful admission note for patient with id 2486033
# Failed admission note for patient with id 3435584
# Failed admission note for patient with id 2005326
# Successful admission note for patient with id 4780609
# Failed admission note for patient with id 3847653
# Successful admission note for patient with id 4757775
# Failed admission note for patient with id 707137
# Successful admission note for patient with id 4925218
# Failed admission note for patient with id 2551064
# Successful admission note for patient with id 741336
# Successful admission note for patient with id 5230991
# Failed admission note for patient with id 839359
# Successful admission note for patient with id 3606052
# Successful admission note for patient with id 1289359
# Failed admission note for patient with id 3074441
# Successful admission note for patient with id 3816282
# Failed admission note for patient with id 512661
# Failed admission note for patient with id 866408
# Successful admission note for patient with id 2153599
# Failed admission note for patient with id 2258118
# Failed admission note for patient with id 380088
# Failed admission note for patient with id 2167827
# Failed admission note for patient with id 543132
# Failed admission note for patient with id 4047328
# Successful admission note for patient with id 3865435
# Successful admission note for patient with id 2764716
# Failed admission note for patient with id 590803
# Failed admission note for patient with id 3058725
# Failed admission note for patient with id 3704912
# Failed admission note for patient with id 584476
# Successful admission note for patient with id 163597
# Failed admission note for patient with id 761780
# Successful admission note for patient with id 3227883
# Successful admission note for patient with id 5209615
# Successful admission note for patient with id 5016810
# Successful admission note for patient with id 2591533
# Successful admission note for patient with id 4581999
# Successful admission note for patient with id 3431191
# Failed admission note for patient with id 887788
# Successful admission note for patient with id 4689580
# Failed admission note for patient with id 1258923
# Failed admission note for patient with id 2934720
# Failed admission note for patient with id 4114004
# Successful admission note for patient with id 1240412
# Successful admission note for patient with id 4717110
# Successful admission note for patient with id 4521698
# Failed admission note for patient with id 2472277
# Successful admission note for patient with id 3102114
# Failed admission note for patient with id 2429640
# Failed admission note for patient with id 2401485
# Successful admission note for patient with id 3873882
# Successful admission note for patient with id 993611
# Failed admission note for patient with id 1119537
# Failed admission note for patient with id 2935833
# Failed admission note for patient with id 3642194
# Failed admission note for patient with id 1770930
# Failed admission note for patient with id 4539225
# Failed admission note for patient with id 2198556
# Failed admission note for patient with id 4239390
# Successful admission note for patient with id 4533137
# Successful admission note for patient with id 1464030
# Failed admission note for patient with id 2258306
# Failed admission note for patient with id 2244076
# Successful admission note for patient with id 1338261
# Successful admission note for patient with id 1737881
# Failed admission note for patient with id 4546585
# Failed admission note for patient with id 4087007
# Successful admission note for patient with id 4333581
# Failed admission note for patient with id 47850
# Successful admission note for patient with id 1628069
# Successful admission note for patient with id 5211075
# Successful admission note for patient with id 1699512
# Failed admission note for patient with id 466485
# Failed admission note for patient with id 794999
# Failed admission note for patient with id 1965753
# Failed admission note for patient with id 4099106
# Failed admission note for patient with id 1104040
# Failed admission note for patient with id 1800084
# Failed admission note for patient with id 609073
# Failed admission note for patient with id 4899833
# Failed admission note for patient with id 3103958
# Failed admission note for patient with id 4494676
# Failed admission note for patient with id 1478948
# Failed admission note for patient with id 942342
# Successful admission note for patient with id 1383102
# Successful admission note for patient with id 4495921
# Failed admission note for patient with id 2824845
# Failed admission note for patient with id 2565487
# Failed admission note for patient with id 56981
# Failed admission note for patient with id 3360408
# Failed admission note for patient with id 223068
# Failed admission note for patient with id 4760329
# Failed admission note for patient with id 1102811
# Failed admission note for patient with id 675501
# Successful admission note for patient with id 2863560
# Failed admission note for patient with id 3892936
# Successful admission note for patient with id 147594
# Successful admission note for patient with id 396966
# Failed admission note for patient with id 1761884
# Successful admission note for patient with id 1745244
# Successful admission note for patient with id 1491070
# Failed admission note for patient with id 1768276
# Failed admission note for patient with id 1651234
# Successful admission note for patient with id 4639110
# Failed admission note for patient with id 2254556
# Failed admission note for patient with id 4566786
# Successful admission note for patient with id 3778760
# Failed admission note for patient with id 2472475
# Failed admission note for patient with id 4055719
# Failed admission note for patient with id 1937132
# Failed admission note for patient with id 187621
# Successful admission note for patient with id 2054786
# Successful admission note for patient with id 2764345
# Failed admission note for patient with id 628004
# Failed admission note for patient with id 1589090
# Failed admission note for patient with id 3241055
# Failed admission note for patient with id 2826969
# Failed admission note for patient with id 4442023
# Failed admission note for patient with id 2504032
# Failed admission note for patient with id 2905281
# Successful admission note for patient with id 4686144
# Failed admission note for patient with id 2324457
# Successful admission note for patient with id 4973461
# Failed admission note for patient with id 642276
# Failed admission note for patient with id 2698391
# Successful admission note for patient with id 906698
# Successful admission note for patient with id 4987000
# Successful admission note for patient with id 4290095
# Failed admission note for patient with id 3514647
# Successful admission note for patient with id 958289
# Failed admission note for patient with id 4346274
# Failed admission note for patient with id 1195892
# Successful admission note for patient with id 439642
# Failed admission note for patient with id 3012908
# Successful admission note for patient with id 4890031
# Failed admission note for patient with id 2210683
# Failed admission note for patient with id 4955675
# Failed admission note for patient with id 737465
# Failed admission note for patient with id 4156249
# Failed admission note for patient with id 4139700
# Successful admission note for patient with id 873530
# Failed admission note for patient with id 609632
# Failed admission note for patient with id 98413
# Failed admission note for patient with id 2583494
# Failed admission note for patient with id 92099
# Failed admission note for patient with id 2206048
# Successful admission note for patient with id 4909139
# Failed admission note for patient with id 715605
# Successful admission note for patient with id 4496611
# Failed admission note for patient with id 1200935
# Successful admission note for patient with id 5118799
# Failed admission note for patient with id 1037516
# Failed admission note for patient with id 4119531
# Failed admission note for patient with id 1231186
# Successful admission note for patient with id 3101997
# Successful admission note for patient with id 5177121
# Failed admission note for patient with id 3690564
# Failed admission note for patient with id 4141152
# Failed admission note for patient with id 689743
# Failed admission note for patient with id 1330803
# Failed admission note for patient with id 404382
# Failed admission note for patient with id 5018225
# Failed admission note for patient with id 5164377
# Failed admission note for patient with id 3093221
# Successful admission note for patient with id 5195388
# Successful admission note for patient with id 2856210
# Successful admission note for patient with id 1217805
# Failed admission note for patient with id 168330
# Successful admission note for patient with id 1937893
# Failed admission note for patient with id 4129753
# Failed admission note for patient with id 3154475
# Failed admission note for patient with id 3749566
# Failed admission note for patient with id 4106337
# Successful admission note for patient with id 2002165
# Failed admission note for patient with id 3148351
# Failed admission note for patient with id 3597989
# Failed admission note for patient with id 4939992
# Failed admission note for patient with id 4454431
# Failed admission note for patient with id 4620005
# Failed admission note for patient with id 4639220
# Successful admission note for patient with id 4358965
# Successful admission note for patient with id 3418022
# Successful admission note for patient with id 1642462
# Failed admission note for patient with id 1804377
# Failed admission note for patient with id 175912
# Failed admission note for patient with id 2588087
# Successful admission note for patient with id 1112212
# Failed admission note for patient with id 2569024
# Failed admission note for patient with id 3144409
# Failed admission note for patient with id 3587861
# Successful admission note for patient with id 2723832
# Failed admission note for patient with id 280300
# Failed admission note for patient with id 2079189
# Successful admission note for patient with id 1213578
# Successful admission note for patient with id 5251112
# Failed admission note for patient with id 1266148
# Successful admission note for patient with id 2213830
# Failed admission note for patient with id 2269191
# Successful admission note for patient with id 3333838
# Failed admission note for patient with id 2031737
# Successful admission note for patient with id 1743300
# Failed admission note for patient with id 3030735
# Failed admission note for patient with id 4098910
# Failed admission note for patient with id 2129351
# Successful admission note for patient with id 3983894
# Failed admission note for patient with id 3796097
# Successful admission note for patient with id 1094919
# Successful admission note for patient with id 3020684
# Failed admission note for patient with id 378580
# Failed admission note for patient with id 1077971
# Successful admission note for patient with id 4762634
# Failed admission note for patient with id 3345009
# Failed admission note for patient with id 3811407
# Failed admission note for patient with id 558877
# Failed admission note for patient with id 827316
# Successful admission note for patient with id 3153668
# Failed admission note for patient with id 3707025
# Successful admission note for patient with id 3506805
# Failed admission note for patient with id 339583
# Successful admission note for patient with id 2540316
# Failed admission note for patient with id 171264
# Failed admission note for patient with id 1955596
# Successful admission note for patient with id 3308399
# Failed admission note for patient with id 70323
# Successful admission note for patient with id 4245268
# Failed admission note for patient with id 3523884
# Failed admission note for patient with id 1523334
# Successful admission note for patient with id 962072
# Successful admission note for patient with id 2978268
# Successful admission note for patient with id 4844280
# Successful admission note for patient with id 4340470
# Failed admission note for patient with id 590425
# Failed admission note for patient with id 407445
# Failed admission note for patient with id 846492
# Failed admission note for patient with id 5190755
# Failed admission note for patient with id 3379710
# Failed admission note for patient with id 929995
# Successful admission note for patient with id 3441761
# Successful admission note for patient with id 2558893
# Failed admission note for patient with id 5121039
# Failed admission note for patient with id 2356193
# Successful admission note for patient with id 2505966
# Failed admission note for patient with id 4728666
# Failed admission note for patient with id 4062899
# Successful admission note for patient with id 3975587
# Successful admission note for patient with id 3265790
# Successful admission note for patient with id 1176076
# Successful admission note for patient with id 4506897

# %% [markdown]
# ## Evaluate output

# %%
note_dict = load_from_json('experiment_1.1')

# %% [markdown]
# ### Use LLM for evaluation
#
# In [Experiment 1.0](experiment-1.0.ipynb) I found that the agent wanted to admit people with conditions that did not merit admission. Here I use the agent first tried in [Experiment 1.0.1](experiment-1.0.1.ipynb) to evaluate the admission decision. The text prompt is [verify_admission_decision.txt](../templates/prompt_templates/verify_admission_decision.txt). The agent is given the admission note, and asked to act as a senior colleague to appraise a junior colleague's decision to admit the patient. The agent returns an agree/disagree decision, and a discharge note. (The reason for adding the discharge note was to encourage the LLM to think about how the patient's condition could be managed without admission)
#
# The code below loops through the 100 admission notes, to evaluate whether an admission decision was the right call. An example is below.

# %%
opinion, reason, discharge_note = verify_admission_decision(persona['Admission_Note'])
print(f"Admission note:\n{persona['Admission_Note'].strip()}\n")
print(f"Senior colleague's opinion:\n{opinion}\n")
print(f"Reason:\n{reason}\n")
print(f"Discharge Note:\n{discharge_note}\n")
# Out:
# Admission note:
# Chief Complaint:
# The patient presented to the Accident & Emergency Department with severe abdominal pain and nausea.
#
# History of Present Illness:
# The patient reports experiencing intermittent upper abdominal pain for the past week. The pain is typically provoked by fatty meals and radiates towards the right shoulder. The patient noticed yellowing of the skin and eyes, along with dark-colored urine. There are no associated fevers, chills, or changes in bowel habits.
#
# Past Medical History:
# The patient has a history of obesity, but there are no previous gastrointestinal issues. There is no known family history of gallbladder disease.
#
# Physical Examination:
# Upon examination, the patient appears uncomfortable and pale. Vital signs reveal a mildly elevated temperature of 37.5°C, heart rate of 90 bpm, blood pressure of 130/80 mmHg, and respiratory rate of 18 breaths per minute. Abdominal examination reveals tenderness in the right upper quadrant with guarding. Murphy's sign is positive.
#
# Assessment:
# Based on the patient's clinical presentation, laboratory results, and physical examination findings, the most likely diagnosis is gallstones causing biliary colic with evidence of obstructive jaundice.
#
# Plan:
# The patient will be admitted for further evaluation. Blood tests will include complete blood count, liver function tests, and pancreatic enzyme levels. An abdominal ultrasound will be performed to confirm the presence of gallstones. Pain management will involve non-steroidal anti-inflammatory drugs and intravenous fluids. The patient will be advised to follow a low-fat diet and may require surgical intervention for sphincterotomy or cholecystectomy depending on the severity of symptoms and presence of complications. Further consultations with gastroenterology and general surgery specialists will be requested.
#
# Senior colleague's opinion:
# agree
#
# Reason:
# In a hospital at capacity, the decision to admit versus discharge hinges on whether a condition can be safely managed outside of the hospital setting. In this case, the patient presented with severe abdominal pain and evidence of obstructive jaundice, which indicates a potential serious condition. Admitting the patient for further evaluation, including blood tests and an abdominal ultrasound, is appropriate to confirm the diagnosis and determine the need for surgical intervention. I agree with the decision to admit the patient.
#
# Discharge Note:
# If the patient were to be discharged, their condition could be managed in outpatient care. They would be advised to follow a low-fat diet and take over-the-counter pain medication as needed. They would also be scheduled for an abdominal ultrasound to confirm the presence of gallstones. Depending on the severity of symptoms and presence of complications, they may require surgical intervention.

# %%
agree_count = 0
failed_count = 0

for id, persona in note_dict.items():
    opinion, reason, discharge_note = verify_admission_decision(persona['Admission_Note']) 
    print(opinion)
    if opinion in ['agree', 'disagree']:
        note_dict[id]['Admission_Note_agreement'] = opinion
        note_dict[id]['Admission_Note_agreement_reason'] = reason
        note_dict[id]['Admission_Note_if_discharged'] = discharge_note

        if opinion == 'agree':
            agree_count += 1
    else: 
        failed_count += 1

print("Number of records where senior colleague agrees: " + str(agree_count))
print("Number of records where agent evaluation failed: " + str(failed_count))
# Out:
# disagree
# disagree
# disagree
# disagree
# agree
# agree
# agree
# agree
# failed on json argument
# disagree
# agree
# disagree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# failed on GPT response
# disagree
# agree
# agree
# disagree
# agree
# agree
# agree
# agree
# disagree
# agree
# agree
# agree
# disagree
# disagree
# disagree
# agree
# disagree
# agree
# disagree
# agree
# agree
# disagree
# disagree
# disagree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# disagree
# disagree
# disagree
# agree
# agree
# disagree
# agree
# disagree
# disagree
# agree
# disagree
# agree
# agree
# agree
# agree
# agree
# agree
# disagree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# disagree
# agree
# agree
# agree
# Number of records where senior colleague agrees: 72
# Number of records where agent evaluation failed: 2

# %%
write_to_json(note_dict, 'experiment_1.1')

# %% [markdown]
# Viewing the output, I note:
# * in 72 of 98 cases (excluding the two failed requests), the senior colleague agreed with the junior colleague. However, in some cases, the 'agree' decision is agreeing with a decision to discharge (eg 1609445) ie the agent has not fully understood the instruction.
#
# Specific cases
# * 450178 and 1609445 both have UTIs. One is a young adult, for which the admission is overruled. The other is elderly for which admission is agreed. This seems appropriate.
# * There are two hypertension cases (where the presenting condition is this) 2585524 a middle aged person, and 2631064 and elderly person. The senior colleague agrees with the admission for the elderly person, for whom the symptoms are more severe. Another case, 2777094 also elderly, is suggested to be more suited to discharge; a harsh decision perhaps given their age of 85+ (although note that the time of day of arrival was not given to the senior colleague in the prompt). Two other hypertension cases, 3543113 and 3546013, are deemed suitable for admission.
