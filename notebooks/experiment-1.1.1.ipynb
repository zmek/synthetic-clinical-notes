# %% [markdown]
# # Experiment 1.1.1
#
# In [Experiment 1.1](experiment-1.1.ipynb), I gave ChatGPT a length of inpatient stay, plus some other patient characteristics, and asked it to generate a likely presenting condition and an admission note. I deployed a second agent to critique the reasoning of the first
#
# One thing I noticed from the output is that surgery is rarely mentioned as a concrete plan. In the [output](../src/data_exports/experiment_1.1_20231008_2106.json) from that experiment there are few mentions of consulting surgical colleagues. In comparison, in the [notebook](explore-nhse-ae-data.ipynb) analysing the original A&E synthetic dataset, it is clear that some patients are admitted for surgery. Possibly, this could be the wording I used in the prompt, which asked for 'medical condition'. That might lead the chatbot to give medical diagnoses over surgical.
#
# There are also other variables that could be given to ChatGPT to attempt to generate an admission note that aligns with the information given in the dataset.
#
# Therefore, here I modify the prompts to include these variables.

# %% [markdown]
# ## Set up

# %%
notebook_name = 'experiment_1.1.1'

# %%
# Reload functions every time
# %load_ext autoreload 
# %autoreload 2

# %%
# Load libraries
import sys
import os
import pandas as pd
import numpy as np
from pathlib import Path

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)


# Import the variables that have been set in the init.py folder in the root directory
# These include a constant called PROJECT_ROOT which stores the absolute path to this folder
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
import init
PROJECT_ROOT = os.getenv("PROJECT_ROOT")

# Add the src folder to sys path, so that the application knows to look there for libraries
sys.path.append(str(Path(PROJECT_ROOT) / 'src'))

# Import function to load data
from data_ingestion.load_data import load_nhse_data

from utils.write_to_json import write_to_json
from utils.load_from_json import load_from_json

from functions.patient_class import Patient

from functions.verify_admission_decision import verify_admission_decision

# %% [markdown]
# ## Load data
#
# Here the function called load_file()
#
# * check if the NHS England datset has already been saved in a local folder called data_store in a parquet format; if so the function returns it
# * if not, it checks for the zip file from the NHSE website and if not downloads it, unzips it and saves it
# * the file is unzipped to csv and read as as pandas dataframe and saved to parquet format

# %%
ed = load_nhse_data(admitted_only=True)
# ed.head()

# %% [markdown]
# ## Generate 100 instances of a patient with admission notes
#
# Here I pick rows from the A&E dataset at random, and generate admission notes for them. I chose to save these to a json file, rather than to individual text files or to SQL, as this is human readable. You can view the full output [here](../src/data_exports/note_dict_20231002_2120.json)
#
# This uses a class definition called Patient(). To see the script, go to [../src/functions/patient_class.py](../src/functions/patient_class.py) An instance of this class, here referred to as a persona, is a single patient. The instance is populated with the variables retrieved from a single row of the ED dataset loaded above.
#
# The steps are the following:
# * select a row from the A&E data
# * pass the row information to the class definition
#
# In addition, as part of creating the persona, a call to ChatGPT is made using the OpenAI API. Certain details about the patient (listed below) are embedded into the prompt to be passed in. ChatGPT is asked to generate a medical condition, and an admission note.
#
# A sub-function [pick_medical_condition()](../src/functions/pick_medical_condition.py) is called to populate three additional attributes of the persona: the diagnosis, their admission note, and their most recent note (which is this case is the admission note, but later this attribute could be something else like a progress note).
#
# The script [pick_medical_condition()](../src/functions/pick_medical_condition.py)
#
# * calls a function [generate_prompt_presenting_condition()](../src/functions/pick_medical_condition.py) (scroll down the file) which populates a ChatGPT prompt with details about the patient. The prompt contains ChatGPT's instructions and requests the ouput in a json format. To see the text of the prompt, go to [pick_medical_condition.txt](../templates/prompt_templates/pick_medical_condition.txt)
# * calls ChatGPT with the prompt. Functions used to call ChatGPT are in [prompt_functions.py](../src/functions/prompt_functions.py)
# * attempts to parse the json output

# %%
attributes = ['Age_Band', 'AE_Arrive_HourOfDay', 'AE_Time_Mins',  'Length_Of_Stay_Days', 'ICD10_Chapter_Code', 'Title', 'Medical_Condition', 'Admission_Note']
note_dict = {}

def row_to_patient(row):
    return Patient(*row)

import numpy as np
np.random.seed(42)

# %%
while len(note_dict.keys()) < 100:

    for index, persona in ed.sample(1).iterrows():

        Pat = row_to_patient(persona)

        if Pat.Admission_Note != '' and 'failed on json' not in str(Pat.Admission_Note):

            print("Successful admission note for patient with id " + str(index))
            
            note_dict[Pat.id] = {}
            note_dict[Pat.id] = {attr: getattr(Pat, attr) for attr in attributes if hasattr(Pat, attr)}

        else: 

            print("Failed admission note for patient with id " + str(index))

    if len(note_dict.keys()) % 10 == 0:
        write_to_json(note_dict, 'experiment_1.1.1')

write_to_json(note_dict, notebook_name)
# Out:
# Failed admission note for patient with id 137805
# Successful admission note for patient with id 2141150
# Failed admission note for patient with id 3652647
# Successful admission note for patient with id 5015254
# Successful admission note for patient with id 1595767
# Successful admission note for patient with id 264087
# Successful admission note for patient with id 5049371
# Successful admission note for patient with id 4888691
# Successful admission note for patient with id 1073520
# Successful admission note for patient with id 4967590
# Successful admission note for patient with id 1918256
# Successful admission note for patient with id 2351032
# Successful admission note for patient with id 2977956
# Successful admission note for patient with id 4680390
# Successful admission note for patient with id 92126
# Successful admission note for patient with id 335597
# Successful admission note for patient with id 2388252
# Successful admission note for patient with id 3626518
# Successful admission note for patient with id 1458722
# Successful admission note for patient with id 2264999
# Successful admission note for patient with id 3795166
# Failed admission note for patient with id 4082636
# Failed admission note for patient with id 519313
# Successful admission note for patient with id 5086557
# Successful admission note for patient with id 4684685
# Successful admission note for patient with id 3089812
# Failed admission note for patient with id 2918136
# Successful admission note for patient with id 1592310
# Successful admission note for patient with id 1456482
# Successful admission note for patient with id 752291
# Successful admission note for patient with id 818243
# Successful admission note for patient with id 3676368
# Failed admission note for patient with id 3660521
# Successful admission note for patient with id 2291941
# Failed admission note for patient with id 3419827
# Successful admission note for patient with id 2596774
# Failed admission note for patient with id 3680138
# Failed admission note for patient with id 2283247
# Successful admission note for patient with id 2631664
# Successful admission note for patient with id 2026470
# Successful admission note for patient with id 2076715
# Successful admission note for patient with id 397422
# Failed admission note for patient with id 3606989
# Successful admission note for patient with id 1458694
# Successful admission note for patient with id 4851867
# Failed admission note for patient with id 3085965
# Successful admission note for patient with id 5060082
# Successful admission note for patient with id 4051787
# Failed admission note for patient with id 3914762
# Successful admission note for patient with id 918738
# Successful admission note for patient with id 68895
# Failed admission note for patient with id 2175712
# Successful admission note for patient with id 994077
# Successful admission note for patient with id 2495668
# Successful admission note for patient with id 2430307
# Failed admission note for patient with id 4056824
# Failed admission note for patient with id 2780965
# Successful admission note for patient with id 114952
# Successful admission note for patient with id 3866966
# Successful admission note for patient with id 2334591
# Failed admission note for patient with id 1980131
# Successful admission note for patient with id 1003951
# Successful admission note for patient with id 4097159
# Successful admission note for patient with id 1154632
# Successful admission note for patient with id 3102454
# Successful admission note for patient with id 1740976
# Successful admission note for patient with id 2785526
# Failed admission note for patient with id 3599702
# Successful admission note for patient with id 2761315
# Successful admission note for patient with id 3882048
# Failed admission note for patient with id 749921
# Successful admission note for patient with id 4625357
# Successful admission note for patient with id 4512654
# Successful admission note for patient with id 4518788
# Successful admission note for patient with id 2085559
# Successful admission note for patient with id 3358416
# Failed admission note for patient with id 1989975
# Successful admission note for patient with id 1066699
# Failed admission note for patient with id 1072922
# Failed admission note for patient with id 739865
# Successful admission note for patient with id 2668892
# Failed admission note for patient with id 4954174
# Failed admission note for patient with id 3629155
# Successful admission note for patient with id 227898
# Failed admission note for patient with id 4050939
# Successful admission note for patient with id 4579212
# Successful admission note for patient with id 4942100
# Successful admission note for patient with id 1545331
# Failed admission note for patient with id 3423741
# Failed admission note for patient with id 3612117
# Successful admission note for patient with id 3053326
# Failed admission note for patient with id 367692
# Failed admission note for patient with id 5256273
# Successful admission note for patient with id 3440771
# Successful admission note for patient with id 1714606
# Successful admission note for patient with id 949907
# Successful admission note for patient with id 1553734
# Failed admission note for patient with id 3387965
# Failed admission note for patient with id 1631906
# Successful admission note for patient with id 232298
# Failed admission note for patient with id 3441735
# Successful admission note for patient with id 4427422
# Successful admission note for patient with id 4811696
# Successful admission note for patient with id 4396685
# Successful admission note for patient with id 471282
# Successful admission note for patient with id 227328
# Successful admission note for patient with id 3567257
# Successful admission note for patient with id 3396468
# Successful admission note for patient with id 3440047
# Successful admission note for patient with id 1540279
# Successful admission note for patient with id 3482810
# Successful admission note for patient with id 1638682
# Successful admission note for patient with id 2187028
# Failed admission note for patient with id 853598
# Failed admission note for patient with id 1582060
# Successful admission note for patient with id 2934272
# Successful admission note for patient with id 959828
# Successful admission note for patient with id 3616730
# Successful admission note for patient with id 2646351
# Successful admission note for patient with id 4958733
# Failed admission note for patient with id 3456461
# Successful admission note for patient with id 1218649
# Failed admission note for patient with id 659001
# Failed admission note for patient with id 390603
# Failed admission note for patient with id 1410112
# Successful admission note for patient with id 2988187
# Successful admission note for patient with id 583811
# Successful admission note for patient with id 1383302
# Successful admission note for patient with id 3706272
# Successful admission note for patient with id 4244494
# Successful admission note for patient with id 48797
# Failed admission note for patient with id 2268870
# Successful admission note for patient with id 3584364
# Successful admission note for patient with id 1858450
# Successful admission note for patient with id 514492
# Failed admission note for patient with id 1449664
# Successful admission note for patient with id 2597572
# Failed admission note for patient with id 5142932
# Failed admission note for patient with id 4422893
# Successful admission note for patient with id 4500967
# Successful admission note for patient with id 2134454

# %% [markdown]
# ## Evaluate output

# %%
note_dict = load_from_json(notebook_name)

data = [{'id': id, **persona} for id, persona in note_dict.items()]
output = pd.DataFrame(data)

# %%
output['Medical_Condition'] = output['Medical_Condition'].str.lower().str.capitalize()

# Dictionary to map similar terms
similar_terms = {
    'Fractured hip': 'Hip fracture',
    'Fracture of hip': 'Hip fracture',
    'Fractured wrist': 'Fracture of the wrist',
    'Gastroesophageal reflux disease (gerd)': 'Gastroesophageal reflux disease',
    'Gastric ulcer': 'Peptic ulcer disease',
    'Kidney stones': 'Kidney stone',
    'Myocardial infarction': 'Heart attack'
}

# Replace similar terms in the array
data = [similar_terms.get(term, term) for term in output['Medical_Condition']]

# Convert the array back to a Pandas Series
output['Medical_Condition_adj'] = pd.Series(data)

# %%
import matplotlib.pyplot as plt



output['Medical_Condition_adj'].value_counts().plot(kind='barh')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.title('Bar Chart of Primary Diagnosis or Condition')
plt.show()

# %% [markdown]
# ### Use LLM for evaluation
#
# In [Experiment 1.0](experiment-1.0.ipynb) I found that the agent wanted to admit people with conditions that did not merit admission. Here I use the agent first tried in [Experiment 1.0.1](experiment-1.0.1.ipynb) to evaluate the admission decision. The text prompt is [verify_admission_decision.txt](../templates/prompt_templates/verify_admission_decision.txt). The agent is given the admission note, and asked to act as a senior colleague to appraise a junior colleague's decision to admit the patient. The agent returns an agree/disagree decision, and a discharge note. (The reason for adding the discharge note was to encourage the LLM to think about how the patient's condition could be managed without admission)
#
# The code below loops through the 100 admission notes, to evaluate whether an admission decision was the right call. An example is below.

# %%
opinion, reason, discharge_note = verify_admission_decision(persona['Admission_Note'])
print(f"Admission note:\n{persona['Admission_Note'].strip()}\n")
print(f"Senior colleague's opinion:\n{opinion}\n")
print(f"Reason:\n{reason}\n")
print(f"Discharge Note:\n{discharge_note}\n")
# Out:
# Admission note:
# Chief Complaint:
# The patient presented to the Accident & Emergency Department with severe abdominal pain and nausea.
#
# History of Present Illness:
# The patient reports experiencing intermittent upper abdominal pain for the past week. The pain is typically provoked by fatty meals and radiates towards the right shoulder. The patient noticed yellowing of the skin and eyes, along with dark-colored urine. There are no associated fevers, chills, or changes in bowel habits.
#
# Past Medical History:
# The patient has a history of obesity, but there are no previous gastrointestinal issues. There is no known family history of gallbladder disease.
#
# Physical Examination:
# Upon examination, the patient appears uncomfortable and pale. Vital signs reveal a mildly elevated temperature of 37.5°C, heart rate of 90 bpm, blood pressure of 130/80 mmHg, and respiratory rate of 18 breaths per minute. Abdominal examination reveals tenderness in the right upper quadrant with guarding. Murphy's sign is positive.
#
# Assessment:
# Based on the patient's clinical presentation, laboratory results, and physical examination findings, the most likely diagnosis is gallstones causing biliary colic with evidence of obstructive jaundice.
#
# Plan:
# The patient will be admitted for further evaluation. Blood tests will include complete blood count, liver function tests, and pancreatic enzyme levels. An abdominal ultrasound will be performed to confirm the presence of gallstones. Pain management will involve non-steroidal anti-inflammatory drugs and intravenous fluids. The patient will be advised to follow a low-fat diet and may require surgical intervention for sphincterotomy or cholecystectomy depending on the severity of symptoms and presence of complications. Further consultations with gastroenterology and general surgery specialists will be requested.
#
# Senior colleague's opinion:
# agree
#
# Reason:
# In a hospital at capacity, the decision to admit versus discharge hinges on whether a condition can be safely managed outside of the hospital setting. In this case, the patient presented with severe abdominal pain and evidence of obstructive jaundice, which indicates a potential serious condition. Admitting the patient for further evaluation, including blood tests and an abdominal ultrasound, is appropriate to confirm the diagnosis and determine the need for surgical intervention. I agree with the decision to admit the patient.
#
# Discharge Note:
# If the patient were to be discharged, their condition could be managed in outpatient care. They would be advised to follow a low-fat diet and take over-the-counter pain medication as needed. They would also be scheduled for an abdominal ultrasound to confirm the presence of gallstones. Depending on the severity of symptoms and presence of complications, they may require surgical intervention.

# %%
agree_count = 0
failed_count = 0
opinion_list = []

for id, persona in note_dict.items():
    opinion, reason, discharge_note = verify_admission_decision(persona['Admission_Note']) 
    opinion_list.append(opinion)

    print(opinion)
    if opinion in ['agree', 'disagree']:
        note_dict[id]['Admission_Note_agreement'] = opinion
        note_dict[id]['Admission_Note_agreement_reason'] = reason
        note_dict[id]['Admission_Note_if_discharged'] = discharge_note

        if opinion == 'agree':
            agree_count += 1
    else: 
        failed_count += 1

# Add the 'opinion' values to the existing DataFrame
output['opinion'] = opinion_list

print("Number of records where senior colleague agrees: " + str(agree_count))
print("Number of records where agent evaluation failed: " + str(failed_count))
# Out:
# agree
# disagree
# agree
# agree
# disagree
# disagree
# agree
# disagree
# agree
# agree
# agree
# agree
# disagree
# agree
# agree
# agree
# disagree
# agree
# disagree
# disagree
# disagree
# disagree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# disagree
# agree
# disagree
# disagree
# agree
# agree
# agree
# agree
# agree
# agree
# disagree
# disagree
# agree
# agree
# agree
# agree
# disagree
# agree
# agree
# agree
# agree
# agree
# agree
# disagree
# agree
# disagree
# agree
# agree
# agree
# agree
# agree
# agree
# agree
# disagree
# agree
# agree
# disagree
# disagree
# agree
# agree
# disagree
# agree
# agree
# agree
# disagree
# agree
# agree
# disagree
# failed on json argument
# agree
# disagree
# agree
# agree
# agree
# agree
# agree
# disagree
# agree
# agree
# agree
# agree
# disagree
# agree
# agree
# agree
# agree
# agree
# agree
# Number of records where senior colleague agrees: 72
# Number of records where agent evaluation failed: 1

# %%
write_to_json(note_dict, notebook_name)

# %%
colors = ['blue', 'orange', 'grey'] 

df_stacked = output[output.opinion != 'failed on json argument'].pivot_table(index='Medical_Condition_adj', 
                            columns='opinion', 
                            aggfunc='size',
                            fill_value=0)

ax = df_stacked.plot(kind='barh', stacked=True, color=colors)

ax.set_title('Agreement with Admission Decision by Diagnosis')
ax.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# Viewing the output which is [here](../src/data_exports/experiment_1.1_20231008_2106.json), I note:
# * in 72 of 98 cases (excluding the two failed requests), the senior colleague agreed with the junior colleague. However, in some cases, the 'agree' decision is agreeing with a decision to discharge (eg 1609445) ie the agent has not fully understood the instruction.
#
# Specific cases
# * 450178 and 1609445 both have UTIs. One is a young adult, for whom the senior colleague disagrees with the admission decision. The other is elderly for whom admission is agreed. This seems appropriate.
# * There are two hypertension cases (where the presenting condition is this) 2585524 a middle aged person, and 2631064 and elderly person. The senior colleague agrees with the admission for the elderly person, for whom the symptoms are more severe. Another case, 2777094 also elderly, is suggested to be more suited to discharge; a harsh decision perhaps given their age of 85+ (although note that the time of day of arrival was not given to the senior colleague in the prompt). Two other hypertension cases, 3543113 and 3546013, are deemed suitable for admission.
